# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Welcome!</title>
#     <style>
#         body {
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             height: 100vh;
#             background: linear-gradient(135deg, #ff7eb3, #ff758c, #ff7eb3);
#             color: white;
#             font-family: 'Poppins', sans-serif;
#             text-align: center;
#             overflow: hidden;
#         }
#         .container {
#             background: rgba(0, 0, 0, 0.4);
#             padding: 30px;
#             border-radius: 15px;
#             box-shadow: 0 10px 20px rgba(0, 0, 0, 0.3);
#             animation: popUp 1s ease-in-out;
#         }
#         h1 {
#             font-size: 3rem;
#             font-weight: bold;
#             animation: fadeIn 2s ease-in-out;
#         }
#         p {
#             font-size: 1.4rem;
#             margin-top: 10px;
#             opacity: 0.8;
#         }
#         @keyframes fadeIn {
#             from { opacity: 0; transform: translateY(-20px); }
#             to { opacity: 1; transform: translateY(0); }
#         }
#         @keyframes popUp {
#             from { transform: scale(0.8); opacity: 0; }
#             to { transform: scale(1); opacity: 1; }
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <h1>🌟 Welcome to My Jupyter Notebook! 🌟</h1>
#          <p>Discover insights, uncover trends, and craft smarter strategies for the next big campaign.</p>
#     </div>
# </body>
# </html>

# %% [markdown]
# <img src="abnkkk.jpg" alt="Girl in a jacket" width="10000" height="600">

# %% [markdown]
# <div style="
#     border: 3px solid #28a745;
#     border-radius: 10px;
#     padding: 20px;
#     text-align: center;
#     background-color: #f0fdf4;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2);
# ">
#     <h1 style="
#         color: #28a745;
#         font-family: 'Arial', sans-serif;
#         font-size: 36px;
#         font-weight: bold;
#         letter-spacing: 2px;
#         text-transform: uppercase;
#     ">
#         📚 Import Libraries ⚙️
#     </h1>
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div style="
#     border: 3px solid #007bff;
#     border-radius: 10px;
#     padding: 20px;
#     text-align: center;
#     background-color: #f8f9fa;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2);
# ">
#     <h1 style="
#         color: #007bff;
#         font-family: 'Arial', sans-serif;
#         font-size: 36px;
#         font-weight: bold;
#         letter-spacing: 2px;
#         text-transform: uppercase;
#     ">
#         🚀 Read & Explore the Data 📊
#     </h1>
# </div>

# %%
# Read Data
df= pd.read_csv("bank.csv")
df.head(10)
# Out:
#    age         job   marital  education  balance housing loan  contact  day  \
# 0   59      admin.   married  secondary     2343     yes   no  unknown    5
# 1   56      admin.   married  secondary       45      no   no  unknown    5
# 2   41  technician   married  secondary     1270     yes   no  unknown    5
# 3   55    services   married  secondary     2476     yes   no  unknown    5
# 4   54      admin.   married   tertiary      184      no   no  unknown    5
# 5   42  management    single   tertiary        0     yes  yes  unknown    5
# 6   56  management   married   tertiary      830     yes  yes  unknown    6
# 7   60     retired  divorced  secondary      545     yes   no  unknown    6
# 8   37  technician   married  secondary        1     yes   no  unknown    6
# 9   28    services    single  secondary     5090     yes   no  unknown    6
#
#   month  duration  campaign  pdays  previous deposit
# 0   may      1042         1     -1         0     yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11162 entries, 0 to 11161
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        11162 non-null  int64
#  1   job        11162 non-null  object
#  2   marital    11162 non-null  object
#  3   education  11162 non-null  object
#  4   balance    11162 non-null  int64
#  5   housing    11162 non-null  object
#  6   loan       11162 non-null  object
#  7   contact    11162 non-null  object
#  8   day        11162 non-null  int64
#  9   month      11162 non-null  object
#  10  duration   11162 non-null  int64
#  11  campaign   11162 non-null  int64
#  12  pdays      11162 non-null  int64
#  13  previous   11162 non-null  int64
#  14  deposit    11162 non-null  object
# dtypes: int64(7), object(8)
# memory usage: 1.3+ MB

# %%
#check The unique Data to udnerstand the Data
for col in df.columns:
    print(f"{col} {df[col].unique()}---> {df[col].nunique()}")
    print(20*"-")
# Out:
# age [59 56 41 55 54 42 60 37 28 38 30 29 46 31 35 32 49 43 26 40 33 23 48 45
#  36 52 53 39 57 51 44 24 50 27 34 47 25 58 61 68 75 22 69 66 85 72 90 67
#  71 21 74 65 62 83 70 76 77 19 73 63 20 78 95 64 79 82 18 86 84 87 92 81
#  80 93 88 89]---> 76
# --------------------
# job ['admin.' 'technician' 'services' 'management' 'retired' 'blue-collar'
#  'unemployed' 'entrepreneur' 'housemaid' 'unknown' 'self-employed'
#  'student']---> 12
# --------------------
# marital ['married' 'single' 'divorced']---> 3
# --------------------
# education ['secondary' 'tertiary' 'primary' 'unknown']---> 4
# --------------------
# balance [2343   45 1270 ... 1594 2593 -134]---> 3805
# --------------------
# housing ['yes' 'no']---> 2
# --------------------
# loan ['no' 'yes']---> 2
# --------------------
# contact ['unknown' 'cellular' 'telephone']---> 3
# --------------------
# day [ 5  6  7  8  9 12 13 14 15 16 19 20 21 23 26 27 28 29 30  2  3  4 11 17
#  18 24  1 10 22 25 31]---> 31
# ...

# %%
d_typs=pd.DataFrame({"Data types":df.dtypes}).T
d_typs
# Out:
#               age     job marital education balance housing    loan contact  \
# Data types  int64  object  object    object   int64  object  object  object
#
#               day   month duration campaign  pdays previous deposit
# Data types  int64  object    int64    int64  int64    int64  object

# %%
# change the object column to categories 
obj_col = df.select_dtypes("object").columns
df[obj_col]= df[obj_col].astype("category")
# split numerical  and categorical columns 
num_col = df.select_dtypes("number").columns
cat_col = df.select_dtypes("category").columns
num_col,cat_col
# Out:
# (Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object'),
#  Index(['job', 'marital', 'education', 'housing', 'loan', 'contact', 'month',
#         'deposit'],
#        dtype='object'))

# %%
#check Nulls
df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# deposit      0
# dtype: int64

# %%
#check Duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.describe(include='number').T
# Out:
#             count         mean          std     min    25%    50%      75%  \
# age       11162.0    41.231948    11.913369    18.0   32.0   39.0    49.00
# balance   11162.0  1528.538524  3225.413326 -6847.0  122.0  550.0  1708.00
# day       11162.0    15.658036     8.420740     1.0    8.0   15.0    22.00
# duration  11162.0   371.993818   347.128386     2.0  138.0  255.0   496.00
# campaign  11162.0     2.508421     2.722077     1.0    1.0    2.0     3.00
# pdays     11162.0    51.330407   108.758282    -1.0   -1.0   -1.0    20.75
# previous  11162.0     0.832557     2.292007     0.0    0.0    0.0     1.00
#
#               max
# age          95.0
# balance   81204.0
# day          31.0
# duration   3881.0
# campaign     63.0
# pdays       854.0
# previous     58.0

# %%
df.describe(include='category').T
# Out:
#            count unique         top  freq
# job        11162     12  management  2566
# marital    11162      3     married  6351
# education  11162      4   secondary  5476
# housing    11162      2          no  5881
# loan       11162      2          no  9702
# contact    11162      3    cellular  8042
# month      11162     12         may  2824
# deposit    11162      2          no  5873

# %%
#check for outlires 
plt.figure(figsize=(18,15))
sns.boxplot(df[num_col])
plt.show()

# %% [markdown]
# <p> .We note that there is some columns have some outlires , let's check it out deeply</p>

# %%
for col in num_col:
    Q1 = df[col].quantile(.25)
    Q3 = df[col].quantile(.75)
    IQR = Q3 - Q1
    Lower_Fence = Q1 - 1.5 * IQR
    Upper_Fence = Q3 + 1.5 * IQR
    Lower_Outliers = df[df[col] < Lower_Fence][col].values
    Upper_Outliers = df[df[col] > Upper_Fence][col].values
    df[col].replace(Lower_Outliers, Lower_Fence, inplace=True)
    df[col].replace(Upper_Outliers, Upper_Fence, inplace=True)

# %%
num_cols = df.select_dtypes("number").columns
plt.figure(figsize=(8, 3))
for i, col in enumerate(num_cols,1):
    plt.subplot(4, 2, i)
    sns.boxplot(df[col], orient="h")
    plt.title(f"{col} boxplot")
plt.subplots_adjust(hspace=.6, wspace=.5)
plt.show()

# %%
plt.figure(figsize=(20,18))
for i, col in enumerate(num_col,1) :
    plt.subplot(2,4,i)
    sns.histplot(df[col],kde=True)
plt.subplots_adjust(wspace=0.4,hspace=0.3)

# %%
# Let's check the correlation
plt.figure(figsize=(20,18))
sns.heatmap(df.corr(numeric_only=True),cbar=False,cmap='Blues',annot=True)
plt.show()

# %% [markdown]
# ##### Let's Explore the Numericacl columns deeply

# %%
num_col
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
sns.lineplot(x=df['month'],y=df['duration'],hue=df['deposit'])
# Out:
# <Axes: xlabel='month', ylabel='duration'>

# %%
sns.barplot(data=df,x='deposit',y='duration',palette='mako',ci=False)
plt.show()

# %% [markdown]
# ##### `Note:` From the previous two figures, we realized that the longer the call duration, the higher the number of subscriptions.

# %%
num_col
# Out:
# Index(['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous'], dtype='object')

# %%
sns.scatterplot(data=df,x='age',y='balance')
# Out:
# <Axes: xlabel='age', ylabel='balance'>

# %%
sns.lineplot(data=df , x='age',y='balance')
# Out:
# <Axes: xlabel='age', ylabel='balance'>

# %% [markdown]
# ##### There isn't any relation between tha age and the balance of the customer

# %%
sns.lineplot(data=df,x='age',y='duration')
# Out:
# <Axes: xlabel='age', ylabel='duration'>

# %%
df_filtered = df[df['age'] > 80]
sns.barplot(x='deposit',y= 'age',data=df_filtered)
# Out:
# <Axes: >

# %%
sns.barplot(data=df,x='deposit',y='campaign',ci=False,palette='mako')
# Out:
# <Axes: xlabel='deposit', ylabel='campaign'>

# %%
# Explore the categorical Data
plt.figure(figsize=(20,18))
for i , col in enumerate(cat_col,1):
    plt.subplot(2,4,i)
    sns.countplot(df[col],palette='mako')
plt.subplots_adjust(wspace=.8,hspace=.7)

# %%
df['contact'].replace('unknown','cellular',inplace=True)

# %%
sns.countplot(df['contact'])
# Out:
# <Axes: xlabel='count', ylabel='contact'>

# %% [markdown]
# <div style="
#     border: 3px solid #007bff;
#     border-radius: 10px;
#     padding: 20px;
#     text-align: center;
#     background-color: #f8f9fa;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2);
# ">
#     <h1 style="
#         color: #007bff;
#         font-family: 'Arial', sans-serif;
#         font-size: 36px;
#         font-weight: bold;
#         letter-spacing: 2px;
#         text-transform: uppercase;
#     ">
#         🚀Split Data & Prepare it for the model 📊
#     </h1>
# </div>

# %% [markdown]
# ### Split Data

# %%
from sklearn.model_selection import train_test_split
x= df.drop("deposit",axis=1)
y=df['deposit']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.25,random_state=0)

# %% [markdown]
# ### Normlization Data

# %%
from sklearn.preprocessing import MinMaxScaler
scalr = MinMaxScaler()
x_train[num_col]=scalr.fit_transform(x_train[num_col])
x_test[num_col]=scalr.transform(x_test[num_col])

# %% [markdown]
# ### Encoding

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder
ordinal = ['month','education']
label=['job','contact','loan','housing','marital']
ord=OrdinalEncoder()
lab=LabelEncoder()
x_train[ordinal]=ord.fit_transform(x_train[ordinal])
x_test[ordinal]=ord.transform(x_test[ordinal])
x_train[label]=ord.fit_transform(x_train[label])
x_test[label]=ord.transform(x_test[label])
x_train.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# dtype: int64

# %% [markdown]
# <div style="
#     border: 3px solid #007bff;
#     border-radius: 10px;
#     padding: 20px;
#     text-align: center;
#     background-color: #f8f9fa;
#     box-shadow: 5px 5px 15px rgba(0, 0, 0, 0.2);
# ">
#     <h1 style="
#         color: #007bff;
#         font-family: 'Arial', sans-serif;
#         font-size: 36px;
#         font-weight: bold;
#         letter-spacing: 2px;
#         text-transform: uppercase;
#     ">
#         🚀The Model 📊
#     </h1>
# </div>

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
yp=rfc.predict(x_test)

# %%
accuracy_score(y_test,yp)*100
# Out:
# 82.7660336796847

# %%
#Save  The Model
import pickle
file_name = 'bank_file.sav'
pickle.dump(rfc, open(file_name, 'wb'))
